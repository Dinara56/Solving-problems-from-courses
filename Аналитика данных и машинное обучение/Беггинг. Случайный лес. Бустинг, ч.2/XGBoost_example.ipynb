# %%
import pandas as pd
import numpy as np

import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder

from matplotlib import pyplot

# %%
# !gdown 1cvCNt9EL-NurjFEJU-iRPG56ae535O3h
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1cvCNt9EL-NurjFEJU-iRPG56ae535O3h
# To: /content/Bank_Customer_Churn_Prediction.csv
# 100% 562k/562k [00:00<00:00, 71.8MB/s]

# %%
data = pd.read_csv('/content/Bank_Customer_Churn_Prediction.csv')
data.head(5)
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
data['country'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
data['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
dct = {'Female': 0, 'Male': 1}
data['gender'] = data['gender'].map(dct)

# %%
data['gender'].unique()
# Out:
# array([0, 1])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  int64
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(9), object(1)
# memory usage: 937.6+ KB

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    data.drop(['churn', 'customer_id'], axis=1),
    data['churn'],
    test_size=0.3,
    stratify=data['churn'],
    random_state=42)

# %%
cat_columns = X_train.dtypes[X_train.dtypes == 'object'].index
num_columns = X_train.dtypes[X_train.dtypes != 'object'].index

# %%
# заменяем пропуски в количественных переменных средними
for c in num_columns:
    X_train[c].fillna(X_train[c].mean(), inplace=True)
    X_valid[c].fillna(X_train[c].mean(), inplace=True)

# %%
# заменяем пропуски в категориальных переменных модами
for c in cat_columns:
    X_train[c].fillna(X_train[c].value_counts().index[0], inplace=True)
    X_valid[c].fillna(X_train[c].value_counts().index[0], inplace=True)

# %%
labelenc = LabelEncoder()
for c in cat_columns:
    lbl = LabelEncoder()
    lbl.fit(X_train[c])
    X_train[c] = lbl.transform(X_train[c])
    X_valid[c] = lbl.transform(X_valid[c])

# %%
features = list(X_train.columns)
features
# Out:
# ['credit_score',
#  'country',
#  'gender',
#  'age',
#  'tenure',
#  'balance',
#  'products_number',
#  'credit_card',
#  'active_member',
#  'estimated_salary']

# %%
X_train
# Out:
#       credit_score  country  gender  age  tenure    balance  products_number  \
# 9136           595        0       1   20       4   95830.43                1
# 6410           689        2       0   63       1       0.00                2
# 2607           814        0       1   31       1  118870.92                1
# 3201           722        0       1   20       6       0.00                2
# 3330           738        0       1   18       4       0.00                2
# ...            ...      ...     ...  ...     ...        ...              ...
# 1467           624        1       0   35       0  180303.24                2
# 4644           712        2       1   74       5       0.00                2
# 8942           667        0       0   37       9   71786.90                2
# 2935           687        2       1   35       8  100988.39                2
# 6206           802        2       1   51       7       0.00                1
#
#       credit_card  active_member  estimated_salary
# 9136            1              0         177738.98
# 6410            1              1         186526.12
# 2607            1              0         101704.19
# 3201            1              0         195486.28
# 3330            1              1          47799.15
# ...           ...            ...               ...
# 1467            1              0         163587.90
# 4644            0              0         151425.82
# 8942            1              1          67734.79
# 2935            1              0          22247.27
# 6206            0              1          40855.79
#
# [7000 rows x 10 columns]

# %%
# создаем объекты DMatrix
dtrain = xgb.DMatrix(data=X_train,
                     label=y_train,
                     feature_names=features
                     )
dvalid = xgb.DMatrix(data=X_valid,
                     label=y_valid)

# %%
# задаем значения параметров и гиперпараметров
params = {
    'objective': 'binary:logistic',
    'eta': 0.05,
    'max_depth': 4,
    'seed': 42,
    'eval_metric': 'auc',
    'verbosity': 0
}

# задаем количество итераций
num_rounds = 100

# %%
# задаем наборы, для которых будем отслеживать
# метрику, заданную с помощью eval_metric
evallist = [(dtrain, 'train'), (dvalid, 'valid')]
# обучаем модель с функцией потерь по умолчанию
# (логистической функцией потерь)
xgb_model = xgb.train(params, dtrain, num_rounds, evallist)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:723: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# [0]	train-auc:0.81469	valid-auc:0.84008
# [1]	train-auc:0.81504	valid-auc:0.84013
# [2]	train-auc:0.81484	valid-auc:0.83915
# [3]	train-auc:0.81958	valid-auc:0.83825
# [4]	train-auc:0.82366	valid-auc:0.84350
# [5]	train-auc:0.82548	valid-auc:0.84348
# [6]	train-auc:0.82547	valid-auc:0.84419
# [7]	train-auc:0.82821	valid-auc:0.84607
# [8]	train-auc:0.83264	valid-auc:0.84937
# [9]	train-auc:0.83458	valid-auc:0.85168
# [10]	train-auc:0.83489	valid-auc:0.85107
# [11]	train-auc:0.83663	valid-auc:0.85218
# [12]	train-auc:0.83715	valid-auc:0.85316
# [13]	train-auc:0.83932	valid-auc:0.85524
# [14]	train-auc:0.84027	valid-auc:0.85561
# [15]	train-auc:0.84130	valid-auc:0.85699
# [16]	train-auc:0.84163	valid-auc:0.85643
# [17]	train-auc:0.84205	valid-auc:0.85683
# [18]	train-auc:0.84244	valid-auc:0.85678
# [19]	train-auc:0.84384	valid-auc:0.85864
# [20]	train-auc:0.84442	valid-auc:0.85945
# [21]	train-auc:0.84581	valid-auc:0.86017
# [22]	train-auc:0.84651	valid-auc:0.86086
# [23]	train-auc:0.84721	valid-auc:0.86125
# [24]	train-auc:0.84747	valid-auc:0.86118
# [25]	train-auc:0.84896	valid-auc:0.86210
# [26]	train-auc:0.84943	valid-auc:0.86166
# [27]	train-auc:0.84993	valid-auc:0.86190
# [28]	train-auc:0.85053	valid-auc:0.86244
# [29]	train-auc:0.85149	valid-auc:0.86306
# [30]	train-auc:0.85204	valid-auc:0.86272
# [31]	train-auc:0.85254	valid-auc:0.86297
# [32]	train-auc:0.85335	valid-auc:0.86335
# [33]	train-auc:0.85355	valid-auc:0.86325
# [34]	train-auc:0.85412	valid-auc:0.86425
# [35]	train-auc:0.85466	valid-auc:0.86467
# [36]	train-auc:0.85531	valid-auc:0.86511
# [37]	train-auc:0.85616	valid-auc:0.86549
# [38]	train-auc:0.85665	valid-auc:0.86577
# [39]	train-auc:0.85788	valid-auc:0.86656
# [40]	train-auc:0.85864	valid-auc:0.86706
# [41]	train-auc:0.85931	valid-auc:0.86743
# [42]	train-auc:0.86031	valid-auc:0.86769
# [43]	train-auc:0.86094	valid-auc:0.86809
# [44]	train-auc:0.86176	valid-auc:0.86839
# [45]	train-auc:0.86255	valid-auc:0.86865
# [46]	train-auc:0.86324	valid-auc:0.86896
# [47]	train-auc:0.86382	valid-auc:0.86927
# [48]	train-auc:0.86431	valid-auc:0.86937
# [49]	train-auc:0.86500	valid-auc:0.86974
# [50]	train-auc:0.86540	valid-auc:0.86999
# [51]	train-auc:0.86608	valid-auc:0.87024
# [52]	train-auc:0.86683	valid-auc:0.87057
# [53]	train-auc:0.86733	valid-auc:0.87090
# [54]	train-auc:0.86757	valid-auc:0.87106
# [55]	train-auc:0.86823	valid-auc:0.87118
# [56]	train-auc:0.86854	valid-auc:0.87139
# [57]	train-auc:0.86887	valid-auc:0.87146
# [58]	train-auc:0.86932	valid-auc:0.87149
# [59]	train-auc:0.86972	valid-auc:0.87177
# [60]	train-auc:0.86999	valid-auc:0.87170
# [61]	train-auc:0.87026	valid-auc:0.87189
# [62]	train-auc:0.87082	valid-auc:0.87188
# [63]	train-auc:0.87138	valid-auc:0.87241
# [64]	train-auc:0.87247	valid-auc:0.87284
# [65]	train-auc:0.87289	valid-auc:0.87283
# [66]	train-auc:0.87321	valid-auc:0.87304
# [67]	train-auc:0.87346	valid-auc:0.87302
# [68]	train-auc:0.87383	valid-auc:0.87316
# [69]	train-auc:0.87433	valid-auc:0.87353
# [70]	train-auc:0.87468	valid-auc:0.87384
# [71]	train-auc:0.87531	valid-auc:0.87395
# [72]	train-auc:0.87551	valid-auc:0.87408
# [73]	train-auc:0.87596	valid-auc:0.87417
# [74]	train-auc:0.87613	valid-auc:0.87427
# [75]	train-auc:0.87630	valid-auc:0.87439
# [76]	train-auc:0.87705	valid-auc:0.87494
# [77]	train-auc:0.87735	valid-auc:0.87513
# [78]	train-auc:0.87768	valid-auc:0.87528
# [79]	train-auc:0.87786	valid-auc:0.87534
# [80]	train-auc:0.87825	valid-auc:0.87559
# [81]	train-auc:0.87862	valid-auc:0.87563
# [82]	train-auc:0.87892	valid-auc:0.87572
# [83]	train-auc:0.87914	valid-auc:0.87580
# [84]	train-auc:0.87940	valid-auc:0.87600
# [85]	train-auc:0.87958	valid-auc:0.87611
# [86]	train-auc:0.87969	valid-auc:0.87608
# [87]	train-auc:0.87996	valid-auc:0.87610
# [88]	train-auc:0.88023	valid-auc:0.87621
# [89]	train-auc:0.88048	valid-auc:0.87642
# [90]	train-auc:0.88068	valid-auc:0.87658
# [91]	train-auc:0.88102	valid-auc:0.87678
# [92]	train-auc:0.88125	valid-auc:0.87699
# [93]	train-auc:0.88174	valid-auc:0.87690
# [94]	train-auc:0.88178	valid-auc:0.87701
# [95]	train-auc:0.88187	valid-auc:0.87697
# [96]	train-auc:0.88225	valid-auc:0.87703
# [97]	train-auc:0.88229	valid-auc:0.87715
# [98]	train-auc:0.88257	valid-auc:0.87710
# [99]	train-auc:0.88296	valid-auc:0.87703

# %%
# записываем вероятности
preds_prob = xgb_model.predict(dvalid)
# вычисляем AUC-ROC на проверочной выборке
print("AUC-ROC на проверочной выборке: {:.3f}".format(
    roc_auc_score(y_valid, preds_prob)))
# Out:
# AUC-ROC на проверочной выборке: 0.877

# %%
# пишем пользовательскую логистическую функцию потерь,
# добавив понижающую корректировку гессиана
def custom_obj(preds, dtrain):
    labels = dtrain.get_label()
    preds = 1.0 / (1.0 + np.exp(-preds))
    grad = preds - labels
    hess_correction = 0.02
    hess = preds * (1.0 - preds) - hess_correction
    return grad, hess

# %%
# задаем значения параметров и гиперпараметров
params2 = {
    'eta': 0.05,
    'max_depth': 4,
    'seed': 42,
    'eval_metric': 'auc',
    'verbosity': 0
}
xgb_model_custom_loss = xgb.train(params2,
                                  dtrain,
                                  num_boost_round=100,
                                  evals=evallist,
                                  obj=custom_obj)
# Out:
# [0]	train-auc:0.81476	valid-auc:0.84053
# [1]	train-auc:0.81564	valid-auc:0.84053
# [2]	train-auc:0.82297	valid-auc:0.84275
# [3]	train-auc:0.82576	valid-auc:0.84646
# [4]	train-auc:0.82777	valid-auc:0.84616
# [5]	train-auc:0.82937	valid-auc:0.84691
# [6]	train-auc:0.83216	valid-auc:0.85011
# [7]	train-auc:0.83114	valid-auc:0.84894
# [8]	train-auc:0.83285	valid-auc:0.85058
# [9]	train-auc:0.83328	valid-auc:0.85075
# [10]	train-auc:0.83640	valid-auc:0.85235
# [11]	train-auc:0.83719	valid-auc:0.85341
# [12]	train-auc:0.83755	valid-auc:0.85295
# [13]	train-auc:0.83843	valid-auc:0.85468
# [14]	train-auc:0.83855	valid-auc:0.85497
# [15]	train-auc:0.83980	valid-auc:0.85547
# [16]	train-auc:0.84061	valid-auc:0.85583
# [17]	train-auc:0.84136	valid-auc:0.85665
# [18]	train-auc:0.84089	valid-auc:0.85647
# [19]	train-auc:0.84183	valid-auc:0.85719
# [20]	train-auc:0.84184	valid-auc:0.85734
# [21]	train-auc:0.84463	valid-auc:0.85949
# [22]	train-auc:0.84591	valid-auc:0.86101
# [23]	train-auc:0.84684	valid-auc:0.86143
# [24]	train-auc:0.84804	valid-auc:0.86225
# [25]	train-auc:0.84830	valid-auc:0.86257
# [26]	train-auc:0.84888	valid-auc:0.86221
# [27]	train-auc:0.84927	valid-auc:0.86270
# [28]	train-auc:0.84962	valid-auc:0.86311
# [29]	train-auc:0.85074	valid-auc:0.86377
# [30]	train-auc:0.85225	valid-auc:0.86497
# [31]	train-auc:0.85261	valid-auc:0.86503
# [32]	train-auc:0.85367	valid-auc:0.86588
# [33]	train-auc:0.85406	valid-auc:0.86620
# [34]	train-auc:0.85530	valid-auc:0.86676
# [35]	train-auc:0.85556	valid-auc:0.86673
# [36]	train-auc:0.85604	valid-auc:0.86667
# [37]	train-auc:0.85701	valid-auc:0.86729
# [38]	train-auc:0.85738	valid-auc:0.86735
# [39]	train-auc:0.85779	valid-auc:0.86752
# [40]	train-auc:0.85855	valid-auc:0.86787
# [41]	train-auc:0.85949	valid-auc:0.86824
# [42]	train-auc:0.86054	valid-auc:0.86827
# [43]	train-auc:0.86110	valid-auc:0.86850
# [44]	train-auc:0.86168	valid-auc:0.86898
# [45]	train-auc:0.86251	valid-auc:0.86934
# [46]	train-auc:0.86318	valid-auc:0.86959
# [47]	train-auc:0.86414	valid-auc:0.87035
# [48]	train-auc:0.86490	valid-auc:0.87033
# [49]	train-auc:0.86578	valid-auc:0.87077
# [50]	train-auc:0.86670	valid-auc:0.87071
# [51]	train-auc:0.86735	valid-auc:0.87083
# [52]	train-auc:0.86787	valid-auc:0.87099
# [53]	train-auc:0.86829	valid-auc:0.87094
# [54]	train-auc:0.86904	valid-auc:0.87088
# [55]	train-auc:0.86956	valid-auc:0.87118
# [56]	train-auc:0.87009	valid-auc:0.87114
# [57]	train-auc:0.87023	valid-auc:0.87141
# [58]	train-auc:0.87093	valid-auc:0.87139
# [59]	train-auc:0.87207	valid-auc:0.87232
# [60]	train-auc:0.87238	valid-auc:0.87231
# [61]	train-auc:0.87302	valid-auc:0.87245
# [62]	train-auc:0.87349	valid-auc:0.87246
# [63]	train-auc:0.87386	valid-auc:0.87253
# [64]	train-auc:0.87477	valid-auc:0.87308
# [65]	train-auc:0.87524	valid-auc:0.87310
# [66]	train-auc:0.87548	valid-auc:0.87331
# [67]	train-auc:0.87599	valid-auc:0.87314
# [68]	train-auc:0.87622	valid-auc:0.87346
# [69]	train-auc:0.87651	valid-auc:0.87367
# [70]	train-auc:0.87669	valid-auc:0.87389
# [71]	train-auc:0.87719	valid-auc:0.87390
# [72]	train-auc:0.87736	valid-auc:0.87408
# [73]	train-auc:0.87751	valid-auc:0.87433
# [74]	train-auc:0.87767	valid-auc:0.87441
# [75]	train-auc:0.87787	valid-auc:0.87468
# [76]	train-auc:0.87843	valid-auc:0.87509
# [77]	train-auc:0.87866	valid-auc:0.87519
# [78]	train-auc:0.87877	valid-auc:0.87517
# [79]	train-auc:0.87897	valid-auc:0.87526
# [80]	train-auc:0.87906	valid-auc:0.87544
# [81]	train-auc:0.87932	valid-auc:0.87551
# [82]	train-auc:0.87953	valid-auc:0.87561
# [83]	train-auc:0.87992	valid-auc:0.87559
# [84]	train-auc:0.88059	valid-auc:0.87593
# [85]	train-auc:0.88060	valid-auc:0.87612
# [86]	train-auc:0.88095	valid-auc:0.87601
# [87]	train-auc:0.88138	valid-auc:0.87636
# [88]	train-auc:0.88153	valid-auc:0.87632
# [89]	train-auc:0.88183	valid-auc:0.87643
# [90]	train-auc:0.88190	valid-auc:0.87654
# [91]	train-auc:0.88220	valid-auc:0.87672
# [92]	train-auc:0.88262	valid-auc:0.87669
# [93]	train-auc:0.88274	valid-auc:0.87688
# [94]	train-auc:0.88279	valid-auc:0.87692
# [95]	train-auc:0.88300	valid-auc:0.87701
# [96]	train-auc:0.88314	valid-auc:0.87712
# [97]	train-auc:0.88346	valid-auc:0.87732
# [98]	train-auc:0.88351	valid-auc:0.87745
# [99]	train-auc:0.88361	valid-auc:0.87737

# %%
# записываем вероятности
preds_prob = xgb_model_custom_loss.predict(dvalid)
# вычисляем AUC-ROC на проверочной выборке
print("AUC-ROC на проверочной выборке: {:.3f}".format(
    roc_auc_score(y_valid, preds_prob)))
# Out:
# AUC-ROC на проверочной выборке: 0.877

# %%
# обучаем модель с функцией потерь по умолчанию (логистической
# функцией потерь), используя перекрестную проверку
xgb.cv(params,
       dtrain,
       num_boost_round=100,
       nfold=5,
       as_pandas=True,
       show_stdv=True,
       stratified=True,
       verbose_eval=True,
       shuffle=True)
# Out:
# [0]	train-auc:0.81612+0.00307	test-auc:0.80554+0.01364
# [1]	train-auc:0.81829+0.00363	test-auc:0.80796+0.01367
# [2]	train-auc:0.82073+0.00174	test-auc:0.81300+0.01605
# [3]	train-auc:0.82486+0.00227	test-auc:0.81654+0.01918
# [4]	train-auc:0.82660+0.00396	test-auc:0.81676+0.01617
# [5]	train-auc:0.82970+0.00434	test-auc:0.81859+0.01675
# [6]	train-auc:0.83055+0.00334	test-auc:0.82145+0.01653
# [7]	train-auc:0.83208+0.00261	test-auc:0.82217+0.01681
# [8]	train-auc:0.83395+0.00396	test-auc:0.82405+0.01707
# [9]	train-auc:0.83565+0.00368	test-auc:0.82584+0.01779
# [10]	train-auc:0.83814+0.00319	test-auc:0.82880+0.01721
# [11]	train-auc:0.83936+0.00341	test-auc:0.83013+0.01742
# [12]	train-auc:0.84019+0.00303	test-auc:0.83149+0.01762
# [13]	train-auc:0.84101+0.00358	test-auc:0.83143+0.01723
# [14]	train-auc:0.84184+0.00337	test-auc:0.83248+0.01701
# [15]	train-auc:0.84265+0.00309	test-auc:0.83370+0.01710
# [16]	train-auc:0.84346+0.00328	test-auc:0.83467+0.01715
# [17]	train-auc:0.84372+0.00321	test-auc:0.83490+0.01733
# [18]	train-auc:0.84445+0.00339	test-auc:0.83541+0.01716
# [19]	train-auc:0.84492+0.00332	test-auc:0.83570+0.01680
# [20]	train-auc:0.84604+0.00290	test-auc:0.83622+0.01709
# [21]	train-auc:0.84674+0.00298	test-auc:0.83697+0.01724
# [22]	train-auc:0.84773+0.00306	test-auc:0.83713+0.01673
# [23]	train-auc:0.84824+0.00304	test-auc:0.83819+0.01677
# [24]	train-auc:0.84945+0.00334	test-auc:0.83900+0.01606
# [25]	train-auc:0.85015+0.00311	test-auc:0.83936+0.01646
# [26]	train-auc:0.85086+0.00274	test-auc:0.84016+0.01572
# [27]	train-auc:0.85155+0.00313	test-auc:0.84007+0.01589
# [28]	train-auc:0.85207+0.00308	test-auc:0.84039+0.01575
# [29]	train-auc:0.85307+0.00303	test-auc:0.84055+0.01600
# [30]	train-auc:0.85368+0.00304	test-auc:0.84088+0.01590
# [31]	train-auc:0.85440+0.00303	test-auc:0.84139+0.01552
# [32]	train-auc:0.85507+0.00317	test-auc:0.84127+0.01562
# [33]	train-auc:0.85554+0.00311	test-auc:0.84134+0.01554
# [34]	train-auc:0.85641+0.00294	test-auc:0.84155+0.01553
# [35]	train-auc:0.85715+0.00297	test-auc:0.84209+0.01528
# [36]	train-auc:0.85785+0.00300	test-auc:0.84190+0.01523
# [37]	train-auc:0.85879+0.00265	test-auc:0.84219+0.01522
# [38]	train-auc:0.85957+0.00271	test-auc:0.84307+0.01514
# [39]	train-auc:0.86025+0.00278	test-auc:0.84368+0.01510
# [40]	train-auc:0.86097+0.00289	test-auc:0.84412+0.01478
# [41]	train-auc:0.86174+0.00285	test-auc:0.84451+0.01453
# [42]	train-auc:0.86243+0.00291	test-auc:0.84530+0.01440
# [43]	train-auc:0.86297+0.00298	test-auc:0.84543+0.01447
# [44]	train-auc:0.86376+0.00302	test-auc:0.84549+0.01431
# [45]	train-auc:0.86440+0.00300	test-auc:0.84621+0.01422
# [46]	train-auc:0.86516+0.00303	test-auc:0.84670+0.01414
# [47]	train-auc:0.86583+0.00299	test-auc:0.84731+0.01409
# [48]	train-auc:0.86657+0.00304	test-auc:0.84741+0.01419
# [49]	train-auc:0.86717+0.00318	test-auc:0.84757+0.01415
# [50]	train-auc:0.86797+0.00304	test-auc:0.84804+0.01392
# [51]	train-auc:0.86864+0.00307	test-auc:0.84827+0.01387
# [52]	train-auc:0.86932+0.00312	test-auc:0.84860+0.01395
# [53]	train-auc:0.86967+0.00311	test-auc:0.84884+0.01407
# [54]	train-auc:0.87030+0.00299	test-auc:0.84927+0.01395
# [55]	train-auc:0.87078+0.00289	test-auc:0.84925+0.01412
# [56]	train-auc:0.87128+0.00293	test-auc:0.84950+0.01393
# [57]	train-auc:0.87185+0.00276	test-auc:0.84968+0.01390
# [58]	train-auc:0.87240+0.00291	test-auc:0.84995+0.01399
# [59]	train-auc:0.87288+0.00286	test-auc:0.85003+0.01418
# [60]	train-auc:0.87344+0.00277	test-auc:0.85024+0.01396
# [61]	train-auc:0.87395+0.00277	test-auc:0.85034+0.01401
# [62]	train-auc:0.87435+0.00280	test-auc:0.85033+0.01404
# [63]	train-auc:0.87484+0.00282	test-auc:0.85063+0.01394
# [64]	train-auc:0.87526+0.00271	test-auc:0.85076+0.01378
# [65]	train-auc:0.87573+0.00279	test-auc:0.85081+0.01379
# [66]	train-auc:0.87623+0.00278	test-auc:0.85103+0.01392
# [67]	train-auc:0.87652+0.00277	test-auc:0.85118+0.01375
# [68]	train-auc:0.87692+0.00275	test-auc:0.85120+0.01368
# [69]	train-auc:0.87736+0.00275	test-auc:0.85137+0.01391
# [70]	train-auc:0.87780+0.00276	test-auc:0.85171+0.01369
# [71]	train-auc:0.87818+0.00274	test-auc:0.85187+0.01343
# [72]	train-auc:0.87855+0.00282	test-auc:0.85182+0.01351
# [73]	train-auc:0.87897+0.00287	test-auc:0.85199+0.01351
# [74]	train-auc:0.87938+0.00286	test-auc:0.85205+0.01339
# [75]	train-auc:0.87969+0.00292	test-auc:0.85230+0.01344
# [76]	train-auc:0.88006+0.00294	test-auc:0.85270+0.01342
# [77]	train-auc:0.88039+0.00288	test-auc:0.85269+0.01334
# [78]	train-auc:0.88087+0.00295	test-auc:0.85276+0.01319
# [79]	train-auc:0.88116+0.00307	test-auc:0.85287+0.01331
# [80]	train-auc:0.88150+0.00310	test-auc:0.85305+0.01329
# [81]	train-auc:0.88189+0.00297	test-auc:0.85320+0.01316
# [82]	train-auc:0.88207+0.00304	test-auc:0.85313+0.01322
# [83]	train-auc:0.88252+0.00301	test-auc:0.85318+0.01332
# [84]	train-auc:0.88274+0.00304	test-auc:0.85330+0.01333
# [85]	train-auc:0.88311+0.00319	test-auc:0.85343+0.01329
# [86]	train-auc:0.88337+0.00329	test-auc:0.85331+0.01340
# [87]	train-auc:0.88363+0.00323	test-auc:0.85326+0.01349
# [88]	train-auc:0.88385+0.00321	test-auc:0.85342+0.01345
# [89]	train-auc:0.88409+0.00328	test-auc:0.85336+0.01336
# [90]	train-auc:0.88432+0.00326	test-auc:0.85345+0.01351
# [91]	train-auc:0.88458+0.00341	test-auc:0.85351+0.01344
# [92]	train-auc:0.88490+0.00342	test-auc:0.85347+0.01337
# [93]	train-auc:0.88524+0.00338	test-auc:0.85348+0.01328
# [94]	train-auc:0.88548+0.00353	test-auc:0.85364+0.01328
# [95]	train-auc:0.88569+0.00348	test-auc:0.85379+0.01319
# [96]	train-auc:0.88609+0.00337	test-auc:0.85395+0.01322
# [97]	train-auc:0.88638+0.00336	test-auc:0.85388+0.01309
# [98]	train-auc:0.88659+0.00333	test-auc:0.85394+0.01312
# [99]	train-auc:0.88676+0.00329	test-auc:0.85398+0.01298
#     train-auc-mean  train-auc-std  test-auc-mean  test-auc-std
# 0         0.816124       0.003068       0.805543      0.013643
# 1         0.818286       0.003631       0.807960      0.013667
# 2         0.820729       0.001735       0.813001      0.016053
# 3         0.824860       0.002273       0.816536      0.019176
# 4         0.826600       0.003958       0.816764      0.016173
# ..             ...            ...            ...           ...
# 95        0.885690       0.003482       0.853785      0.013192
# 96        0.886087       0.003368       0.853955      0.013219
# 97        0.886382       0.003356       0.853881      0.013091
# 98        0.886586       0.003331       0.853945      0.013118
# 99        0.886759       0.003285       0.853983      0.012984
#
# [100 rows x 4 columns]

# %%
# обучаем модель с пользовательской логистической функцией
# потерь, используя перекрестную проверку
xgb.cv(params2,
       dtrain,
       num_boost_round=100,
       nfold=5,
       obj=custom_obj,
       as_pandas=True,
       show_stdv=True,
       stratified=True,
       verbose_eval=True,
       shuffle=True)
# Out:
# [0]	train-auc:0.81208+0.00297	test-auc:0.80397+0.01548
# [1]	train-auc:0.81744+0.00415	test-auc:0.80931+0.01906
# [2]	train-auc:0.82045+0.00510	test-auc:0.80939+0.01771
# [3]	train-auc:0.82476+0.00672	test-auc:0.81593+0.01759
# [4]	train-auc:0.82867+0.00476	test-auc:0.82077+0.01601
# [5]	train-auc:0.83092+0.00491	test-auc:0.82262+0.01547
# [6]	train-auc:0.83242+0.00287	test-auc:0.82441+0.01663
# [7]	train-auc:0.83298+0.00318	test-auc:0.82614+0.01617
# [8]	train-auc:0.83534+0.00345	test-auc:0.82721+0.01646
# [9]	train-auc:0.83597+0.00306	test-auc:0.82893+0.01714
# [10]	train-auc:0.83684+0.00297	test-auc:0.82928+0.01681
# [11]	train-auc:0.83813+0.00340	test-auc:0.82934+0.01703
# [12]	train-auc:0.83835+0.00330	test-auc:0.82974+0.01718
# [13]	train-auc:0.83940+0.00350	test-auc:0.83101+0.01707
# [14]	train-auc:0.84012+0.00347	test-auc:0.83146+0.01708
# [15]	train-auc:0.84112+0.00377	test-auc:0.83292+0.01695
# [16]	train-auc:0.84236+0.00379	test-auc:0.83420+0.01675
# [17]	train-auc:0.84334+0.00384	test-auc:0.83483+0.01704
# [18]	train-auc:0.84384+0.00359	test-auc:0.83493+0.01721
# [19]	train-auc:0.84465+0.00369	test-auc:0.83584+0.01707
# [20]	train-auc:0.84513+0.00385	test-auc:0.83598+0.01698
# [21]	train-auc:0.84554+0.00351	test-auc:0.83685+0.01709
# [22]	train-auc:0.84666+0.00384	test-auc:0.83732+0.01683
# [23]	train-auc:0.84803+0.00336	test-auc:0.83779+0.01713
# [24]	train-auc:0.84883+0.00334	test-auc:0.83834+0.01667
# [25]	train-auc:0.84975+0.00338	test-auc:0.83852+0.01676
# [26]	train-auc:0.85056+0.00340	test-auc:0.83865+0.01707
# [27]	train-auc:0.85184+0.00351	test-auc:0.83936+0.01651
# [28]	train-auc:0.85252+0.00333	test-auc:0.83990+0.01700
# [29]	train-auc:0.85360+0.00347	test-auc:0.83994+0.01694
# [30]	train-auc:0.85432+0.00345	test-auc:0.84027+0.01706
# [31]	train-auc:0.85504+0.00316	test-auc:0.84053+0.01700
# [32]	train-auc:0.85611+0.00320	test-auc:0.84097+0.01674
# [33]	train-auc:0.85673+0.00343	test-auc:0.84148+0.01678
# [34]	train-auc:0.85743+0.00322	test-auc:0.84143+0.01644
# [35]	train-auc:0.85815+0.00327	test-auc:0.84155+0.01643
# [36]	train-auc:0.85873+0.00329	test-auc:0.84164+0.01664
# [37]	train-auc:0.85947+0.00310	test-auc:0.84167+0.01656
# [38]	train-auc:0.86035+0.00295	test-auc:0.84204+0.01627
# [39]	train-auc:0.86087+0.00265	test-auc:0.84230+0.01668
# [40]	train-auc:0.86158+0.00273	test-auc:0.84247+0.01655
# [41]	train-auc:0.86228+0.00271	test-auc:0.84273+0.01645
# [42]	train-auc:0.86328+0.00271	test-auc:0.84325+0.01614
# [43]	train-auc:0.86377+0.00273	test-auc:0.84359+0.01613
# [44]	train-auc:0.86447+0.00273	test-auc:0.84374+0.01624
# [45]	train-auc:0.86518+0.00265	test-auc:0.84419+0.01596
# [46]	train-auc:0.86602+0.00253	test-auc:0.84440+0.01546
# [47]	train-auc:0.86657+0.00253	test-auc:0.84458+0.01545
# [48]	train-auc:0.86724+0.00265	test-auc:0.84477+0.01536
# [49]	train-auc:0.86835+0.00253	test-auc:0.84521+0.01510
# [50]	train-auc:0.86926+0.00267	test-auc:0.84570+0.01513
# [51]	train-auc:0.86972+0.00266	test-auc:0.84618+0.01515
# [52]	train-auc:0.87033+0.00272	test-auc:0.84643+0.01479
# [53]	train-auc:0.87114+0.00245	test-auc:0.84729+0.01497
# [54]	train-auc:0.87207+0.00243	test-auc:0.84766+0.01485
# [55]	train-auc:0.87265+0.00243	test-auc:0.84762+0.01485
# [56]	train-auc:0.87333+0.00224	test-auc:0.84780+0.01464
# [57]	train-auc:0.87408+0.00250	test-auc:0.84842+0.01429
# [58]	train-auc:0.87452+0.00252	test-auc:0.84871+0.01431
# [59]	train-auc:0.87507+0.00248	test-auc:0.84882+0.01462
# [60]	train-auc:0.87556+0.00248	test-auc:0.84911+0.01458
# [61]	train-auc:0.87609+0.00253	test-auc:0.84932+0.01462
# [62]	train-auc:0.87691+0.00267	test-auc:0.84978+0.01441
# [63]	train-auc:0.87737+0.00269	test-auc:0.85009+0.01436
# [64]	train-auc:0.87787+0.00254	test-auc:0.85021+0.01410
# [65]	train-auc:0.87857+0.00275	test-auc:0.85036+0.01417
# [66]	train-auc:0.87920+0.00283	test-auc:0.85055+0.01395
# [67]	train-auc:0.87955+0.00290	test-auc:0.85075+0.01383
# [68]	train-auc:0.87992+0.00288	test-auc:0.85101+0.01381
# [69]	train-auc:0.88043+0.00294	test-auc:0.85125+0.01371
# [70]	train-auc:0.88090+0.00288	test-auc:0.85137+0.01373
# [71]	train-auc:0.88124+0.00301	test-auc:0.85157+0.01388
# [72]	train-auc:0.88159+0.00304	test-auc:0.85166+0.01377
# [73]	train-auc:0.88182+0.00305	test-auc:0.85199+0.01359
# [74]	train-auc:0.88211+0.00302	test-auc:0.85224+0.01346
# [75]	train-auc:0.88258+0.00311	test-auc:0.85235+0.01367
# [76]	train-auc:0.88300+0.00299	test-auc:0.85228+0.01345
# [77]	train-auc:0.88342+0.00320	test-auc:0.85255+0.01328
# [78]	train-auc:0.88380+0.00327	test-auc:0.85238+0.01342
# [79]	train-auc:0.88408+0.00316	test-auc:0.85275+0.01351
# [80]	train-auc:0.88425+0.00315	test-auc:0.85287+0.01336
# [81]	train-auc:0.88444+0.00317	test-auc:0.85302+0.01332
# [82]	train-auc:0.88487+0.00316	test-auc:0.85321+0.01334
# [83]	train-auc:0.88519+0.00322	test-auc:0.85328+0.01329
# [84]	train-auc:0.88546+0.00312	test-auc:0.85335+0.01347
# [85]	train-auc:0.88590+0.00301	test-auc:0.85328+0.01337
# [86]	train-auc:0.88626+0.00290	test-auc:0.85367+0.01325
# [87]	train-auc:0.88651+0.00293	test-auc:0.85374+0.01317
# [88]	train-auc:0.88674+0.00291	test-auc:0.85375+0.01318
# [89]	train-auc:0.88703+0.00268	test-auc:0.85381+0.01301
# [90]	train-auc:0.88737+0.00277	test-auc:0.85361+0.01294
# [91]	train-auc:0.88762+0.00265	test-auc:0.85371+0.01300
# [92]	train-auc:0.88803+0.00282	test-auc:0.85369+0.01294
# [93]	train-auc:0.88834+0.00277	test-auc:0.85378+0.01294
# [94]	train-auc:0.88865+0.00263	test-auc:0.85393+0.01314
# [95]	train-auc:0.88880+0.00261	test-auc:0.85392+0.01316
# [96]	train-auc:0.88909+0.00268	test-auc:0.85393+0.01308
# [97]	train-auc:0.88930+0.00273	test-auc:0.85408+0.01305
# [98]	train-auc:0.88948+0.00279	test-auc:0.85408+0.01297
# [99]	train-auc:0.88971+0.00269	test-auc:0.85415+0.01312
#     train-auc-mean  train-auc-std  test-auc-mean  test-auc-std
# 0         0.812085       0.002972       0.803966      0.015483
# 1         0.817441       0.004145       0.809306      0.019056
# 2         0.820446       0.005098       0.809394      0.017714
# 3         0.824762       0.006718       0.815925      0.017587
# 4         0.828668       0.004757       0.820770      0.016012
# ..             ...            ...            ...           ...
# 95        0.888800       0.002608       0.853919      0.013158
# 96        0.889089       0.002683       0.853926      0.013079
# 97        0.889298       0.002731       0.854084      0.013054
# 98        0.889480       0.002786       0.854081      0.012966
# 99        0.889714       0.002691       0.854154      0.013121
#
# [100 rows x 4 columns]

# %%
# увеличим количество итераций
num_rounds = 1000

# обучаем модель, используя
# раннюю остановку
xgb_model_earlystop = xgb.train(params,
                                dtrain,
                                num_rounds,
                                evallist,
                                early_stopping_rounds=10)
# Out:
# [0]	train-auc:0.81469	valid-auc:0.84008
# [1]	train-auc:0.81504	valid-auc:0.84013
# [2]	train-auc:0.81484	valid-auc:0.83915
# [3]	train-auc:0.81958	valid-auc:0.83825
# [4]	train-auc:0.82366	valid-auc:0.84350
# [5]	train-auc:0.82548	valid-auc:0.84348
# [6]	train-auc:0.82547	valid-auc:0.84419
# [7]	train-auc:0.82821	valid-auc:0.84607
# [8]	train-auc:0.83264	valid-auc:0.84937
# [9]	train-auc:0.83458	valid-auc:0.85168
# [10]	train-auc:0.83489	valid-auc:0.85107
# [11]	train-auc:0.83663	valid-auc:0.85218
# [12]	train-auc:0.83715	valid-auc:0.85316
# [13]	train-auc:0.83932	valid-auc:0.85524
# [14]	train-auc:0.84027	valid-auc:0.85561
# [15]	train-auc:0.84130	valid-auc:0.85699
# [16]	train-auc:0.84163	valid-auc:0.85643
# [17]	train-auc:0.84205	valid-auc:0.85683
# [18]	train-auc:0.84244	valid-auc:0.85678
# [19]	train-auc:0.84384	valid-auc:0.85864
# [20]	train-auc:0.84442	valid-auc:0.85945
# [21]	train-auc:0.84581	valid-auc:0.86017
# [22]	train-auc:0.84651	valid-auc:0.86086
# [23]	train-auc:0.84721	valid-auc:0.86125
# [24]	train-auc:0.84747	valid-auc:0.86118
# [25]	train-auc:0.84896	valid-auc:0.86210
# [26]	train-auc:0.84943	valid-auc:0.86166
# [27]	train-auc:0.84993	valid-auc:0.86190
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:723: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# [28]	train-auc:0.85053	valid-auc:0.86244
# [29]	train-auc:0.85149	valid-auc:0.86306
# [30]	train-auc:0.85204	valid-auc:0.86272
# [31]	train-auc:0.85254	valid-auc:0.86297
# [32]	train-auc:0.85335	valid-auc:0.86335
# [33]	train-auc:0.85355	valid-auc:0.86325
# [34]	train-auc:0.85412	valid-auc:0.86425
# [35]	train-auc:0.85466	valid-auc:0.86467
# [36]	train-auc:0.85531	valid-auc:0.86511
# [37]	train-auc:0.85616	valid-auc:0.86549
# [38]	train-auc:0.85665	valid-auc:0.86577
# [39]	train-auc:0.85788	valid-auc:0.86656
# [40]	train-auc:0.85864	valid-auc:0.86706
# [41]	train-auc:0.85931	valid-auc:0.86743
# [42]	train-auc:0.86031	valid-auc:0.86769
# [43]	train-auc:0.86094	valid-auc:0.86809
# [44]	train-auc:0.86176	valid-auc:0.86839
# [45]	train-auc:0.86255	valid-auc:0.86865
# [46]	train-auc:0.86324	valid-auc:0.86896
# [47]	train-auc:0.86382	valid-auc:0.86927
# [48]	train-auc:0.86431	valid-auc:0.86937
# [49]	train-auc:0.86500	valid-auc:0.86974
# [50]	train-auc:0.86540	valid-auc:0.86999
# [51]	train-auc:0.86608	valid-auc:0.87024
# [52]	train-auc:0.86683	valid-auc:0.87057
# [53]	train-auc:0.86733	valid-auc:0.87090
# [54]	train-auc:0.86757	valid-auc:0.87106
# [55]	train-auc:0.86823	valid-auc:0.87118
# [56]	train-auc:0.86854	valid-auc:0.87139
# [57]	train-auc:0.86887	valid-auc:0.87146
# [58]	train-auc:0.86932	valid-auc:0.87149
# [59]	train-auc:0.86972	valid-auc:0.87177
# [60]	train-auc:0.86999	valid-auc:0.87170
# [61]	train-auc:0.87026	valid-auc:0.87189
# [62]	train-auc:0.87082	valid-auc:0.87188
# [63]	train-auc:0.87138	valid-auc:0.87241
# [64]	train-auc:0.87247	valid-auc:0.87284
# [65]	train-auc:0.87289	valid-auc:0.87283
# [66]	train-auc:0.87321	valid-auc:0.87304
# [67]	train-auc:0.87346	valid-auc:0.87302
# [68]	train-auc:0.87383	valid-auc:0.87316
# [69]	train-auc:0.87433	valid-auc:0.87353
# [70]	train-auc:0.87468	valid-auc:0.87384
# [71]	train-auc:0.87531	valid-auc:0.87395
# [72]	train-auc:0.87551	valid-auc:0.87408
# [73]	train-auc:0.87596	valid-auc:0.87417
# [74]	train-auc:0.87613	valid-auc:0.87427
# [75]	train-auc:0.87630	valid-auc:0.87439
# [76]	train-auc:0.87705	valid-auc:0.87494
# [77]	train-auc:0.87735	valid-auc:0.87513
# [78]	train-auc:0.87768	valid-auc:0.87528
# [79]	train-auc:0.87786	valid-auc:0.87534
# [80]	train-auc:0.87825	valid-auc:0.87559
# [81]	train-auc:0.87862	valid-auc:0.87563
# [82]	train-auc:0.87892	valid-auc:0.87572
# [83]	train-auc:0.87914	valid-auc:0.87580
# [84]	train-auc:0.87940	valid-auc:0.87600
# [85]	train-auc:0.87958	valid-auc:0.87611
# [86]	train-auc:0.87969	valid-auc:0.87608
# [87]	train-auc:0.87996	valid-auc:0.87610
# [88]	train-auc:0.88023	valid-auc:0.87621
# [89]	train-auc:0.88048	valid-auc:0.87642
# [90]	train-auc:0.88068	valid-auc:0.87658
# [91]	train-auc:0.88102	valid-auc:0.87678
# [92]	train-auc:0.88125	valid-auc:0.87699
# [93]	train-auc:0.88174	valid-auc:0.87690
# [94]	train-auc:0.88178	valid-auc:0.87701
# [95]	train-auc:0.88187	valid-auc:0.87697
# [96]	train-auc:0.88225	valid-auc:0.87703
# [97]	train-auc:0.88229	valid-auc:0.87715
# [98]	train-auc:0.88257	valid-auc:0.87710
# [99]	train-auc:0.88296	valid-auc:0.87703
# [100]	train-auc:0.88315	valid-auc:0.87716
# [101]	train-auc:0.88321	valid-auc:0.87723
# [102]	train-auc:0.88343	valid-auc:0.87735
# [103]	train-auc:0.88354	valid-auc:0.87733
# [104]	train-auc:0.88402	valid-auc:0.87740
# [105]	train-auc:0.88411	valid-auc:0.87748
# [106]	train-auc:0.88435	valid-auc:0.87744
# [107]	train-auc:0.88450	valid-auc:0.87746
# [108]	train-auc:0.88454	valid-auc:0.87748
# [109]	train-auc:0.88497	valid-auc:0.87755
# [110]	train-auc:0.88532	valid-auc:0.87753
# [111]	train-auc:0.88552	valid-auc:0.87772
# [112]	train-auc:0.88557	valid-auc:0.87770
# [113]	train-auc:0.88595	valid-auc:0.87779
# [114]	train-auc:0.88620	valid-auc:0.87777
# [115]	train-auc:0.88630	valid-auc:0.87781
# [116]	train-auc:0.88634	valid-auc:0.87790
# [117]	train-auc:0.88661	valid-auc:0.87789
# [118]	train-auc:0.88667	valid-auc:0.87788
# [119]	train-auc:0.88696	valid-auc:0.87772
# [120]	train-auc:0.88710	valid-auc:0.87771
# [121]	train-auc:0.88715	valid-auc:0.87769
# [122]	train-auc:0.88744	valid-auc:0.87770
# [123]	train-auc:0.88747	valid-auc:0.87775
# [124]	train-auc:0.88759	valid-auc:0.87774
# [125]	train-auc:0.88770	valid-auc:0.87772

# %%
# печатаем наилучшее значение AUC-ROC и номер наилучшей итерации
print("наилучшее значение AUC-ROC: %.5f" % xgb_model_earlystop.best_score)
print("номер наилучшей итерации:", xgb_model_earlystop.best_iteration)
# Out:
# наилучшее значение AUC-ROC: 0.87790
# номер наилучшей итерации: 116

# %%
# обучаем модель, используя перекрестную проверку
# и раннюю остановку
xgb.cv(params,
       dtrain,
       num_boost_round=1000,
       nfold=5,
       as_pandas=True,
       show_stdv=True,
       stratified=True,
       verbose_eval=True,
       early_stopping_rounds=5,
       shuffle=True)
# Out:
# [0]	train-auc:0.81612+0.00307	test-auc:0.80554+0.01364
# [1]	train-auc:0.81829+0.00363	test-auc:0.80796+0.01367
# [2]	train-auc:0.82073+0.00174	test-auc:0.81300+0.01605
# [3]	train-auc:0.82486+0.00227	test-auc:0.81654+0.01918
# [4]	train-auc:0.82660+0.00396	test-auc:0.81676+0.01617
# [5]	train-auc:0.82970+0.00434	test-auc:0.81859+0.01675
# [6]	train-auc:0.83055+0.00334	test-auc:0.82145+0.01653
# [7]	train-auc:0.83208+0.00261	test-auc:0.82217+0.01681
# [8]	train-auc:0.83395+0.00396	test-auc:0.82405+0.01707
# [9]	train-auc:0.83565+0.00368	test-auc:0.82584+0.01779
# [10]	train-auc:0.83814+0.00319	test-auc:0.82880+0.01721
# [11]	train-auc:0.83936+0.00341	test-auc:0.83013+0.01742
# [12]	train-auc:0.84019+0.00303	test-auc:0.83149+0.01762
# [13]	train-auc:0.84101+0.00358	test-auc:0.83143+0.01723
# [14]	train-auc:0.84184+0.00337	test-auc:0.83248+0.01701
# [15]	train-auc:0.84265+0.00309	test-auc:0.83370+0.01710
# [16]	train-auc:0.84346+0.00328	test-auc:0.83467+0.01715
# [17]	train-auc:0.84372+0.00321	test-auc:0.83490+0.01733
# [18]	train-auc:0.84445+0.00339	test-auc:0.83541+0.01716
# [19]	train-auc:0.84492+0.00332	test-auc:0.83570+0.01680
# [20]	train-auc:0.84604+0.00290	test-auc:0.83622+0.01709
# [21]	train-auc:0.84674+0.00298	test-auc:0.83697+0.01724
# [22]	train-auc:0.84773+0.00306	test-auc:0.83713+0.01673
# [23]	train-auc:0.84824+0.00304	test-auc:0.83819+0.01677
# [24]	train-auc:0.84945+0.00334	test-auc:0.83900+0.01606
# [25]	train-auc:0.85015+0.00311	test-auc:0.83936+0.01646
# [26]	train-auc:0.85086+0.00274	test-auc:0.84016+0.01572
# [27]	train-auc:0.85155+0.00313	test-auc:0.84007+0.01589
# [28]	train-auc:0.85207+0.00308	test-auc:0.84039+0.01575
# [29]	train-auc:0.85307+0.00303	test-auc:0.84055+0.01600
# [30]	train-auc:0.85368+0.00304	test-auc:0.84088+0.01590
# [31]	train-auc:0.85440+0.00303	test-auc:0.84139+0.01552
# [32]	train-auc:0.85507+0.00317	test-auc:0.84127+0.01562
# [33]	train-auc:0.85554+0.00311	test-auc:0.84134+0.01554
# [34]	train-auc:0.85641+0.00294	test-auc:0.84155+0.01553
# [35]	train-auc:0.85715+0.00297	test-auc:0.84209+0.01528
# [36]	train-auc:0.85785+0.00300	test-auc:0.84190+0.01523
# [37]	train-auc:0.85879+0.00265	test-auc:0.84219+0.01522
# [38]	train-auc:0.85957+0.00271	test-auc:0.84307+0.01514
# [39]	train-auc:0.86025+0.00278	test-auc:0.84368+0.01510
# [40]	train-auc:0.86097+0.00289	test-auc:0.84412+0.01478
# [41]	train-auc:0.86174+0.00285	test-auc:0.84451+0.01453
# [42]	train-auc:0.86243+0.00291	test-auc:0.84530+0.01440
# [43]	train-auc:0.86297+0.00298	test-auc:0.84543+0.01447
# [44]	train-auc:0.86376+0.00302	test-auc:0.84549+0.01431
# [45]	train-auc:0.86440+0.00300	test-auc:0.84621+0.01422
# [46]	train-auc:0.86516+0.00303	test-auc:0.84670+0.01414
# [47]	train-auc:0.86583+0.00299	test-auc:0.84731+0.01409
# [48]	train-auc:0.86657+0.00304	test-auc:0.84741+0.01419
# [49]	train-auc:0.86717+0.00318	test-auc:0.84757+0.01415
# [50]	train-auc:0.86797+0.00304	test-auc:0.84804+0.01392
# [51]	train-auc:0.86864+0.00307	test-auc:0.84827+0.01387
# [52]	train-auc:0.86932+0.00312	test-auc:0.84860+0.01395
# [53]	train-auc:0.86967+0.00311	test-auc:0.84884+0.01407
# [54]	train-auc:0.87030+0.00299	test-auc:0.84927+0.01395
# [55]	train-auc:0.87078+0.00289	test-auc:0.84925+0.01412
# [56]	train-auc:0.87128+0.00293	test-auc:0.84950+0.01393
# [57]	train-auc:0.87185+0.00276	test-auc:0.84968+0.01390
# [58]	train-auc:0.87240+0.00291	test-auc:0.84995+0.01399
# [59]	train-auc:0.87288+0.00286	test-auc:0.85003+0.01418
# [60]	train-auc:0.87344+0.00277	test-auc:0.85024+0.01396
# [61]	train-auc:0.87395+0.00277	test-auc:0.85034+0.01401
# [62]	train-auc:0.87435+0.00280	test-auc:0.85033+0.01404
# [63]	train-auc:0.87484+0.00282	test-auc:0.85063+0.01394
# [64]	train-auc:0.87526+0.00271	test-auc:0.85076+0.01378
# [65]	train-auc:0.87573+0.00279	test-auc:0.85081+0.01379
# [66]	train-auc:0.87623+0.00278	test-auc:0.85103+0.01392
# [67]	train-auc:0.87652+0.00277	test-auc:0.85118+0.01375
# [68]	train-auc:0.87692+0.00275	test-auc:0.85120+0.01368
# [69]	train-auc:0.87736+0.00275	test-auc:0.85137+0.01391
# [70]	train-auc:0.87780+0.00276	test-auc:0.85171+0.01369
# [71]	train-auc:0.87818+0.00274	test-auc:0.85187+0.01343
# [72]	train-auc:0.87855+0.00282	test-auc:0.85182+0.01351
# [73]	train-auc:0.87897+0.00287	test-auc:0.85199+0.01351
# [74]	train-auc:0.87938+0.00286	test-auc:0.85205+0.01339
# [75]	train-auc:0.87969+0.00292	test-auc:0.85230+0.01344
# [76]	train-auc:0.88006+0.00294	test-auc:0.85270+0.01342
# [77]	train-auc:0.88039+0.00288	test-auc:0.85269+0.01334
# [78]	train-auc:0.88087+0.00295	test-auc:0.85276+0.01319
# [79]	train-auc:0.88116+0.00307	test-auc:0.85287+0.01331
# [80]	train-auc:0.88150+0.00310	test-auc:0.85305+0.01329
# [81]	train-auc:0.88189+0.00297	test-auc:0.85320+0.01316
# [82]	train-auc:0.88207+0.00304	test-auc:0.85313+0.01322
# [83]	train-auc:0.88252+0.00301	test-auc:0.85318+0.01332
# [84]	train-auc:0.88274+0.00304	test-auc:0.85330+0.01333
# [85]	train-auc:0.88311+0.00319	test-auc:0.85343+0.01329
# [86]	train-auc:0.88337+0.00329	test-auc:0.85331+0.01340
# [87]	train-auc:0.88363+0.00323	test-auc:0.85326+0.01349
# [88]	train-auc:0.88385+0.00321	test-auc:0.85342+0.01345
# [89]	train-auc:0.88409+0.00328	test-auc:0.85336+0.01336
# [90]	train-auc:0.88432+0.00326	test-auc:0.85345+0.01351
# [91]	train-auc:0.88458+0.00341	test-auc:0.85351+0.01344
# [92]	train-auc:0.88490+0.00342	test-auc:0.85347+0.01337
# [93]	train-auc:0.88524+0.00338	test-auc:0.85348+0.01328
# [94]	train-auc:0.88548+0.00353	test-auc:0.85364+0.01328
# [95]	train-auc:0.88569+0.00348	test-auc:0.85379+0.01319
# [96]	train-auc:0.88609+0.00337	test-auc:0.85395+0.01322
# [97]	train-auc:0.88638+0.00336	test-auc:0.85388+0.01309
# [98]	train-auc:0.88659+0.00333	test-auc:0.85394+0.01312
# [99]	train-auc:0.88676+0.00329	test-auc:0.85398+0.01298
# [100]	train-auc:0.88705+0.00330	test-auc:0.85400+0.01305
# [101]	train-auc:0.88716+0.00330	test-auc:0.85403+0.01292
# [102]	train-auc:0.88740+0.00333	test-auc:0.85417+0.01297
# [103]	train-auc:0.88763+0.00325	test-auc:0.85404+0.01282
# [104]	train-auc:0.88792+0.00324	test-auc:0.85409+0.01270
# [105]	train-auc:0.88815+0.00329	test-auc:0.85407+0.01275
# [106]	train-auc:0.88834+0.00335	test-auc:0.85412+0.01270
#      train-auc-mean  train-auc-std  test-auc-mean  test-auc-std
# 0          0.816124       0.003068       0.805543      0.013643
# 1          0.818286       0.003631       0.807960      0.013667
# 2          0.820729       0.001735       0.813001      0.016053
# 3          0.824860       0.002273       0.816536      0.019176
# 4          0.826600       0.003958       0.816764      0.016173
# ..              ...            ...            ...           ...
# 98         0.886586       0.003331       0.853945      0.013118
# 99         0.886759       0.003285       0.853983      0.012984
# 100        0.887050       0.003300       0.853997      0.013048
# 101        0.887165       0.003295       0.854029      0.012922
# 102        0.887397       0.003330       0.854166      0.012966
#
# [103 rows x 4 columns]

# %%
# строим график важностей, тип важности - вес
xgb.plot_importance(xgb_model, importance_type='weight');

# %% [markdown]
# Важные гиперпараметры для XGBoost включают:
#
# n_estimators: количество деревьев.
# learning_rate (или eta): скорость обучения.
# max_depth: максимальная глубина деревьев.
# min_child_weight: минимальное количество образцов для разделения узла.
# subsample: доля выборки для каждого дерева.
# colsample_bytree, colsample_bylevel, colsample_bynode: доля признаков, используемых на различных уровнях.
# gamma: минимальное уменьшение потерь для разделения узла.

# %% [markdown]
# **colsample_bytree**:
#
# Определяет долю случайных признаков, которые используются для построения каждого дерева в ансамбле.
# Если colsample_bytree равен 0.8, это означает, что 80% признаков будет случайно выбрано для построения каждого дерева, а оставшиеся 20% не будут использоваться в этом дереве.
# Помогает уменьшить переобучение и улучшить обобщающую способность модели.
#
#
#
# **colsample_bylevel**:
#
# Определяет долю случайных признаков, которые используются на каждом уровне дерева.
# Например, если colsample_bylevel равен 0.8, то на каждом уровне дерева будет использоваться только 80% всех признаков, а оставшиеся 20% не будут использованы на этом уровне.
# Это параметр помогает избежать переобучения, особенно если у вас много признаков и модель может переобучаться на слишком многих признаках.
#
#
#
#
# **colsample_bynode**:
#
# Определяет долю случайных признаков, которые используются при рассмотрении каждого узла дерева.
# Если colsample_bynode равен 0.8, это означает, что для каждого узла будет использоваться только 80% всех признаков, а остальные 20% будут проигнорированы при принятии решения о разделении узла.
# Этот параметр помогает в создании более разнообразных деревьев и улучшает устойчивость модели.
